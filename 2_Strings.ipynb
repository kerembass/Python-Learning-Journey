# %% [markdown]
# <a href="https://colab.research.google.com/github/kerembass/Python-Learning-Journey/blob/main/2_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Strings

# %%
"Hello world!"
# Out:
# 'Hello world!'

# %%
'Hello world!'
# Out:
# 'Hello world!'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "kerem"

# %%
type(name)
# Out:
# str

# %%
"Kerem restaruant"
# Out:
# 'Kerem restaruant'

# %%
"Kerem's restaurant" #important
# Out:
# "Kerem's restaurant"

# %%
name.capitalize() #To capitalize the first letter
# Out:
# 'Kerem'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name.count("e")
# Out:
# 2

# %%
name.count("a")
# Out:
# 0

# %%
name.upper()
# Out:
# 'KEREM'

# %%
name
# Out:
# 'kerem'

# %%
x=10
y=5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'KEREM'

# %%
print(name.upper())
# Out:
# KEREM

# %%
len(name) #length
# Out:
# 5

# %%
name2 = "kerem bas"

# %%
len(name2) #a space is laso a character
# Out:
# 9

# %%
print("kerem \nbas")
# Out:
# kerem
# bas

# %%
#escape char
#\n -> new line
#\t -> tab
