# %% [markdown]
# <a href="https://colab.research.google.com/github/kerembass/Python-Learning-Journey/blob/main/3_IndexingLogicAndCollections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Index

# %%
myString = "hello python" #indexs start from zero

# %%
myString[4]
# Out:
# 'o'

# %%
myString[1]
# Out:
# 'e'

# %%
myString[11]
# Out:
# 'n'

# %%
len(myString)
# Out:
# 12

# %%
len(myString) - 1
# Out:
# 11

# %%
myName = "james hetfield"

# %%
myName[len(myName) - 1]
# Out:
# 'd'

# %%
myName[-1] #more simple
# Out:
# 'd'

# %%
myName[-2]
# Out:
# 'l'

# %%
barcode ="ABCDE123123982"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[1]
# Out:
# 'B'

# %%
barcode[2]
# Out:
# 'C'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
name = "Kerem"

# %%
surname = "Bas"

# %%
fullname = name +" "+ surname

# %%
fullname
# Out:
# 'Kerem Bas'

# %%
fullname * 5
# Out:
# 'Kerem BasKerem BasKerem BasKerem BasKerem Bas'

# %%
100*"a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ABC'

# %% [markdown]
# Slicing

# %%
#starting index, stopping index, stepping size

# %%
#barcode[starting index:stopping index:stepping size]

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[3::1]
# Out:
# 'DE123123982'

# %%
barcode[0:3:1]
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[::-1]
# Out:
# '289321321EDCBA'

# %%
name = "Kerem Bas"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(...) method of builtins.str instance
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.

# %%
name.index("s")
# Out:
# 8

# %%
name.split()
# Out:
# ['Kerem', 'Bas']

# %%
type(name.split())
# Out:
# list

# %% [markdown]
# Lists

# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0] = "a" not true (immutability)

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,40,50,60,70]

# %%
myList[0]
# Out:
# 10

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList[0]
# Out:
# 100

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
myList[len(myList)-1]
# Out:
# 70

# %%
myList[len(myList)-2]
# Out:
# 60

# %%
myList[-1]
# Out:
# 70

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.index(40)
# Out:
# 3

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.insert(2,35)

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 80]

# %%
myList.remove(40)

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70, 80]

# %%
myList.reverse()

# %%
myList
# Out:
# [80, 70, 60, 50, 30, 35, 20, 100]

# %%
myList.sort()

# %%
myList
# Out:
# [20, 30, 35, 50, 60, 70, 80, 100]

# %%
x = input("enter x")
# Out:
# enter x10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y:")
# Out:
# enter y:20

# %%
y
# Out:
# '20'

# %%
z = input("enter z:")
# Out:
# enter z:30

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
inputList
# Out:
# []

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1]*2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %% [markdown]
# Data Type Conversion

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
type(myInteger)
# Out:
# int

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
#int(myString) not true

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1]) * 2
# Out:
# 40

# %%
str(inputList)
# Out:
# "['10', '20', '30']"

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
nameList = ["kerem", "ahmet","mehmet"]

# %%
type(nameList)
# Out:
# list

# %%
mixedList = ["kerem",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixedList
# Out:
# ['kerem', 100, 3.14]

# %%
mixedList[1]
# Out:
# 100

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
#nestedList

# %%
myNestedList = [10,20,3.14,"kerem",[1,2,3]]

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'kerem'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'kerem', [1, 2, 3]]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]
