# %% [markdown]
# <a href="https://colab.research.google.com/github/kerembass/Python-Learning-Journey/blob/main/1_VariablesandDataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 + 8
# Out:
# 11

# %%
4*3
# Out:
# 12

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
5-2
# Out:
# 3

# %% [markdown]
# Variables

# %%
age = 50

# %%
age*3
# Out:
# 150

# %%
age - 7
# Out:
# 43

# %% [markdown]
# Data Type

# %%
type(10)
# Out:
# int

# %%
type(10*3)
# Out:
# int

# %%
type(age*5)
# Out:
# int

# %%
#int -> integer

# %%
type(3.14)
# Out:
# float

# %%
#float -> floating point

# %%
pi = 3.14

# %%
pi*2
# Out:
# 6.28

# %%
x = 20

# %%
myFloat = 1.3443432

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase or snake_case

# %%
#myFloat or my_float

# %% [markdown]
# **Integer vs Float**

# %%
40 / 4
# Out:
# 10.0

# %%
type(40 / 4)
# Out:
# float

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(4.5 - 2)
# Out:
# float

# %%
2*2*2*2*2
# Out:
# 32

# %%
2 ** 5
# Out:
# 32

# %%
10 % 3 #remainder
# Out:
# 1

# %%
type(10%3)
# Out:
# int
